# %%
#Tarea 1.3
while True:
  texto = input('Escriba "salir" para salir: ') #Ciclo while que solo se rompe si el texto que se escribe es salir, si no se escribe salir vuelve a pedirlo.

  if texto == ('salir'):
    break
